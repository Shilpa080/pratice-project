# %% [markdown]
# World Happiness Report

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # Data Frame Description

# %% [markdown]
# In the above data set contains the data of World Happiness Report.The data set contains the columns such like 'Country', 'Region', 'Happiness Rank', 'Standard Error', 'Economy (GDP per Capita)', 'Family','Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)''Generosity', 'Dystopia Residual'], describe the extent to which these factors contribute in evaluating the happiness in each country.on the basis of data set the target is to predict the charges. on the basis of data set the target is to predict the charges. on the basis of data set the target is to predict the Happiness Score

# %% [markdown]
# Checking the null values.

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Observations-There is no null value in dataset.

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [raw]
# observations:
#     1.The mean is more than median(50th percentile)in Trust columns.
#     2.The median is more than mean in Economy,Family,Health columns.
#     3.There is a large difference in 75% percentile and max in Happiness Rank,Freedom,Trust (Government Corruption),Generosity.

# %%
df.describe().all()
# Out:
# Happiness Rank                    True
# Happiness Score                   True
# Standard Error                    True
# Economy (GDP per Capita)         False
# Family                           False
# Health (Life Expectancy)         False
# Freedom                          False
# Trust (Government Corruption)    False
# Generosity                       False
# Dystopia Residual                 True
# dtype: bool

# %% [markdown]
# # EDA

# %% [markdown]
# Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='Country',data=df)
print(df['Country'].value_counts())
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64

# %%
sns.countplot(x='Region',data=df)
print(df['Region'].value_counts())
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
sns.distplot(df['Happiness Score'],kde=True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Density'>

# %%
sns.distplot(df['Standard Error'],kde=True)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(df['Economy (GDP per Capita)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'],kde=True)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'],kde=True)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'],kde=True)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'],kde=True)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# Visualization part is done.

# %% [markdown]
# # Encoding of dataframe

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linecolor='black',linewidth=0.1,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correalation

# %% [markdown]
# Correaltion of the columns with the target column.

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linecolor='black',linewidth=0.1,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking the which column is positively related or negatively correlated with target columns.

# %%
plt.figure(figsize=(22,7))
df.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Since no column has skewness,we will not treat them.

# %% [markdown]
# # Outliers check

# %%
df.dtypes
# Out:
# Country                          float64
# Region                           float64
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df['Happiness Rank'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Standard Error'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Economy (GDP per Capita)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Family'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Health (Life Expectancy)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Freedom'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Trust (Government Corruption)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Generosity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Dystopia Residual'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',subplots=True,layout=(2,6))
# Out:
# Country                             AxesSubplot(0.125,0.536818;0.110714x0.343182)
# Region                           AxesSubplot(0.257857,0.536818;0.110714x0.343182)
# Happiness Rank                   AxesSubplot(0.390714,0.536818;0.110714x0.343182)
# Happiness Score                  AxesSubplot(0.523571,0.536818;0.110714x0.343182)
# Standard Error                   AxesSubplot(0.656429,0.536818;0.110714x0.343182)
# Economy (GDP per Capita)         AxesSubplot(0.789286,0.536818;0.110714x0.343182)
# Family                                 AxesSubplot(0.125,0.125;0.110714x0.343182)
# Health (Life Expectancy)            AxesSubplot(0.257857,0.125;0.110714x0.343182)
# Freedom                             AxesSubplot(0.390714,0.125;0.110714x0.343182)
# Trust (Government Corruption)       AxesSubplot(0.523571,0.125;0.110714x0.343182)
# Generosity                          AxesSubplot(0.656429,0.125;0.110714x0.343182)
# ...

# %% [markdown]
# # Removing outliers

# %%
df.shape
# Out:
# (158, 12)

# %%
from scipy.stats import zscore

# %%
x=df.loc[ : , df.columns != 'Happiness Score']
x
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0      135.0     9.0               1         0.03411
# 1       58.0     9.0               2         0.04884
# 2       37.0     9.0               3         0.03328
# 3      105.0     9.0               4         0.03880
# 4       24.0     5.0               5         0.03553
# ..       ...     ...             ...             ...
# 153    118.0     8.0             154         0.03464
# 154     13.0     8.0             155         0.03656
# 155    136.0     4.0             156         0.05015
# 156     21.0     8.0             157         0.08658
# 157    141.0     8.0             158         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
y=df.iloc[:,-9]
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
z=np.array(zscore(x))
z
# Out:
# array([[ 1.23877001,  1.30025593, -1.72099989, ...,  2.30965159,
#          0.47103971,  0.75825809],
#        [-0.44946522,  1.30025593, -1.69907456, ..., -0.01647953,
#          1.57585637,  1.09285682],
#        [-0.90989302,  1.30025593, -1.67714922, ...,  2.8427738 ,
#          0.8242928 ,  0.71233526],
#        ...,
#        [ 1.26069514, -0.37544095,  1.67742676, ...,  0.38141902,
#          1.85689094, -3.20843049],
#        [-1.26069514,  0.96511655,  1.69935209, ..., -0.35771452,
#         -0.31694987, -0.48198451],
#        [ 1.37032081,  0.96511655,  1.72127743, ..., -0.30180313,
#         -0.5581534 , -0.96361241]])

# %%
thereshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 153], dtype=int64), array([8, 3, 3, 3, 9, 8], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 152      0.0     7.0             153            3.575         0.03084
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
xx=df_new.drop(['Happiness Score'],axis=1)

# %%
xx
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0      135.0     9.0               1         0.03411
# 1       58.0     9.0               2         0.04884
# 2       37.0     9.0               3         0.03328
# 3      105.0     9.0               4         0.03880
# 4       24.0     5.0               5         0.03553
# ..       ...     ...             ...             ...
# 152      0.0     7.0             153         0.03084
# 154     13.0     8.0             155         0.03656
# 155    136.0     4.0             156         0.05015
# 156     21.0     8.0             157         0.08658
# 157    141.0     8.0             158         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %% [markdown]
# percentage of data loss

# %%
Data_loss=((158-152)/158)*100
Data_loss
# Out:
# 3.79746835443038

# %% [markdown]
# # Traning

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
lr=LinearRegression()
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_lr=lr.predict(x_test)
    print('Predicated result price',pred_lr)
    print('Actual price',y_test)
# Out:
# Predicated result price [7.36350649 5.99507922 4.63348108 4.51434305 5.71585347 4.50713698
#  4.5123114  3.95571039 4.68557031 5.00703577 6.78617755 3.90371684
#  6.6697132  5.77038785 5.19376266 4.88452097 4.29670978 4.87598148
#  3.8965039  5.82826543 5.98709727 6.45458725 5.79056555 7.28596668
#  6.16757134 6.29808734 4.85755814 6.9012335  3.81924274 4.69405863
#  5.88904071 5.8476072 ]
# Actual price 7      7.364
# 44     5.995
# 113    4.633
# 120    4.514
# 63     5.716
# 122    4.507
# 121    4.512
# 139    3.956
# 109    4.686
# 92     5.007
# 24     6.786
# 141    3.904
# 26     6.670
# 60     5.770
# 80     5.194
# 97     4.885
# 129    4.297
# 98     4.876
# 142    3.896
# 56     5.828
# 45     5.987
# 33     6.455
# 59     5.791
# 8      7.286
# 40     6.168
# 37     6.298
# 101    4.857
# 19     6.901
# 144    3.819
# 108    4.694
# 51     5.889
# 54     5.848
# Name: Happiness Score, dtype: float64
# ...

# %%
print('mean absolute error:',mean_absolute_error(y_test,pred_lr))
print('mean squared error:',mean_squared_error(y_test,pred_lr))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# mean absolute error: 0.0002521099058288151
# mean squared error: 9.347912668696388e-08
# Root mean squared error: 0.00030574356360676486

# %%
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
print(r2_score(y_test,pred_lr))
# Out:
# 0.9999999331142203

# %% [markdown]
# # Cross valdation of the model

# %%
from sklearn.model_selection import cross_val_score

# %%
train_accurancy=r2_score(y_train,pred_train)
test_accurancy=r2_score(y_test,pred_test)

# %%
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold{j}the cv score is{cv_mean}and accurancy score for training is {train_accurancy}and accurancy for the testing is {test_accurancy}')
    print('\n')
# Out:
# at cross fold2the cv score is0.9999997284501867and accurancy score for training is 0.9999999442155584and accurancy for the testing is 0.9999999331142203
#
#
# at cross fold3the cv score is0.9999994758122854and accurancy score for training is 0.9999999442155584and accurancy for the testing is 0.9999999331142203
#
#
# at cross fold4the cv score is0.9999988371717737and accurancy score for training is 0.9999999442155584and accurancy for the testing is 0.9999999331142203
#
#
# at cross fold5the cv score is0.9999982417917263and accurancy score for training is 0.9999999442155584and accurancy for the testing is 0.9999999331142203
#
#
# at cross fold6the cv score is0.9999971509064253and accurancy score for training is 0.9999999442155584and accurancy for the testing is 0.9999999331142203
#
#
# at cross fold7the cv score is0.99999580182807and accurancy score for training is 0.9999999442155584and accurancy for the testing is 0.9999999331142203
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual charges',fontsize=14)
plt.ylabel('predicted charges',fontsize=14)
plt.title('LinearRegression',fontsize=18)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# observation-Best line is covering most of the data points which shows good fit of our model.

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import  GridSearchCV
from sklearn.linear_model import Lasso

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],
           'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
#final model training
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 94.48910801372226

# %%
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 94.06593466756603

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# -98.41774312062783

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],
           'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion= 'mae', max_features='sqrt')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print('R2score:',rfs*100)
rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score:',rfc*100)
# Out:
# R2score: 94.71380248726663
# cross val score: -292.89786833432555

# %%
import pickle

# %%
filename='world happiness predict'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# # conclusion:

# %%
loaded_model=pickle.load(open('world happiness predict','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 94.71380248726663

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=['predicted','original'])
conclusion
# Out:
#                 0        1        2         3        4        5        6   \
# predicted  5.82059  5.35415  3.72912  4.355055  4.62155  7.25937  6.00557
# original   5.82059  5.35415  3.72912  4.355055  4.62155  7.25937  6.00557
#
#                 7        8        9   ...        22       23       24  \
# predicted  4.39049  7.04185  5.04932  ...  4.794475  3.90868  3.87235
# original   4.39049  7.04185  5.04932  ...  4.794475  3.90868  3.87235
#
#                 25       26       27       28       29        30       31
# predicted  4.84344  5.18755  5.15259  5.95179  4.99196  4.604435  3.86874
# original   4.84344  5.18755  5.15259  5.95179  4.99196  4.604435  3.86874
#
# [2 rows x 32 columns]
